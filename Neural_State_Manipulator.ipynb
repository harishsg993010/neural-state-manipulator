# %%
# !pip install neural-state-manipulator==0.1.0
# Out:
# Collecting neural-state-manipulator==0.1.0
#   Downloading neural_state_manipulator-0.1.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: torch>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from neural-state-manipulator==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: transformers>=4.50.3 in /usr/local/lib/python3.11/dist-packages (from neural-state-manipulator==0.1.0) (4.50.3)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from neural-state-manipulator==0.1.0) (2.0.2)
# Collecting bitsandbytes>=0.45.4 (from neural-state-manipulator==0.1.0)
#   Downloading bitsandbytes-0.45.4-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.6.0->neural-state-manipulator==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->neural-state-manipulator==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.6.0->neural-state-manipulator==0.1.0) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (0.30.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.50.3->neural-state-manipulator==0.1.0) (4.67.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.6.0->neural-state-manipulator==0.1.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.50.3->neural-state-manipulator==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.50.3->neural-state-manipulator==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.50.3->neural-state-manipulator==0.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.50.3->neural-state-manipulator==0.1.0) (2025.1.31)
# Downloading neural_state_manipulator-0.1.0-py3-none-any.whl (12 kB)
# Downloading bitsandbytes-0.45.4-py3-none-manylinux_2_24_x86_64.whl (76.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 MB 31.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes, neural-state-manipulator
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.45.4 neural-state-manipulator-0.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from neural_state_manipulator import NeuralStateManipulator, list_manipulable_layers

# Optional: List manipulable layers in a model
layers = list_manipulable_layers("unsloth/Meta-Llama-3.1-8B-Instruct")

# Initialize the manipulator with your model
manipulator = NeuralStateManipulator("unsloth/Meta-Llama-3.1-8B-Instruct")

# Select specific layers for manipulation
# prefer final layers for example if a model has 30 layers, use layers 28, 29, 30 and same for any layer and here I am using the 15th layer since the model has only 16 layers
target_layers = ['model.layers.30.post_attention_layernorm', 'model.layers.30.mlp.gate_proj']

# Record behavior patterns
formal_text = """
The implementation of artificial intelligence in industrial settings has been
demonstrated to enhance operational efficiency by an average of 27%, according to
recent comprehensive analyses. The methodology employed in these studies involved
rigorous examination of productivity metrics across diverse manufacturing environments.
"""
manipulator.record_behavior_pattern(formal_text, "formal_writing", target_layers)

# Generate text with the formal pattern applied
prompt = "Write about climate change:"
output = manipulator.generate_with_manipulation(
    prompt, "formal_writing", influence_strength=0.5,
    max_new_tokens=300, temperature=0.7
)
print(output)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/956 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Model: unsloth/Meta-Llama-3.1-8B-Instruct
# Total attention layers: 32
# Total MLP layers: 128
# Total other parameter layers: 230
#
# Sample attention layers:
#   - model.layers.0.post_attention_layernorm
#   - model.layers.1.post_attention_layernorm
#   - model.layers.2.post_attention_layernorm
#   - model.layers.3.post_attention_layernorm
#   - model.layers.4.post_attention_layernorm
#
# Sample MLP layers:
#   - model.layers.0.mlp
#   - model.layers.0.mlp.gate_proj
#   - model.layers.0.mlp.up_proj
#   - model.layers.0.mlp.down_proj
#   - model.layers.1.mlp
# Loading unsloth/Meta-Llama-3.1-8B-Instruct...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/55.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# Recorded activation pattern for behavior: formal_writing
# Write about climate change: what it is, its effects, and what we can do to mitigate it.
# Climate change refers to the long-term warming of the planet, which is primarily caused by the increasing levels of greenhouse gases in the Earth's atmosphere. These gases, such as carbon dioxide, methane, and nitrous oxide, trap heat from the sun and prevent it from being released back into space, leading to a rise in global temperatures.
# The effects of climate change are far-reaching and multifaceted. Some of the most notable consequences include:
# Rising sea levels: As the planet warms, the polar ice caps and glaciers are melting, causing sea levels to rise and leading to more frequent and severe coastal flooding and erosion.
# Extreme weather events: Climate change is linked to an increase in extreme weather events such as heatwaves, droughts, and heavy downpours. These events can have devastating consequences, including loss of life, infrastructure damage, and economic losses.
# Water scarcity: Changes in precipitation patterns and increased evaporation due to warmer temperatures are leading to water scarcity in many parts of the world, affecting agriculture, industry, and human consumption.
# Loss of biodiversity: Rising temperatures and changing weather patterns are altering ecosystems and threatening the survival of many plant and animal species.
#
# To mitigate climate change, we must reduce our greenhouse gas emissions and transition to a low-carbon economy. Some strategies include:
#
# Renewable energy: Transitioning to renewable energy sources such as solar and wind power can significantly reduce our reliance on fossil fuels and

# %%
# Record a creative writing style
creative_text = """
Sunlight danced through the leaves, painting the forest floor with shimmering gold.
The ancient trees whispered secrets to one another, their roots intertwined beneath
the soil like old friends holding hands. A fox, clever and quick, darted between shadows.
"""
manipulator.record_behavior_pattern(creative_text, "creative_writing", target_layers)

# Generate with the creative pattern
creative_output = manipulator.generate_with_manipulation(
    prompt, "creative_writing", influence_strength=0.5,
    max_new_tokens=300, temperature=0.7
)
print(creative_output)
# Out:
# Recorded activation pattern for behavior: creative_writing
# Write about climate change: what it is, its effects, and what we can do to mitigate it.
# Climate change refers to the long-term warming of the planet, which is primarily caused by the increasing levels of greenhouse gases in the Earth's atmosphere. These gases, such as carbon dioxide, methane, and nitrous oxide, trap heat from the sun and prevent it from being released back into space, leading to a rise in global temperatures.
# The effects of climate change are far-reaching and multifaceted. Some of the most notable consequences include:
# Rising global temperatures: The average global temperature has risen by about 1°C since the late 1800s, and is projected to continue to rise by another 2-5°C by the end of this century, depending on the level of greenhouse gas emissions.
# More frequent natural disasters: Climate change is leading to an increase in extreme weather events such as droughts, floods, and heatwaves, which can have devastating consequences for communities and ecosystems.
# Sea-level rise: As the planet warms, the polar ice caps and glaciers are melting, causing sea levels to rise. This can lead to coastal erosion, flooding, and saltwater intrusion into freshwater sources.
# Water scarcity: Changes in precipitation patterns and increased evaporation due to warmer temperatures are leading to water scarcity in many parts of the world, affecting agriculture, industry, and human consumption.
# Loss of biodiversity: As temperatures rise, many plant and animal species are unable to adapt or migrate to areas with suitable climates, resulting in

# %%
# Define examples of technical and non-technical text
technical_texts = [
    "The algorithm complexity is O(n log n) in the average case.",
    "Quantum computing utilizes qubits rather than classical bits.",
    "The framework implements dependency injection via constructor parameters."
]
non_technical_texts = [
    "The sunset painted the sky with brilliant colors.",
    "She enjoyed her coffee while reading the morning newspaper.",
    "The dog chased the ball across the grassy field."
]

# Identify neurons associated with technical language
manipulator.capture_concept_neurons(
    technical_texts, non_technical_texts, "technical_concept"
)

# Generate text with technical concept neurons stimulated
technical_output = manipulator.generate_with_concept_neurons(
    "Write about climate change:", "technical_concept",
    influence_strength=0.5, max_new_tokens=300
)
print(technical_output)
# Out:
# Warning: Inconsistent shapes in layer model.layers.0.post_attention_layernorm, skipping
#   Positive shapes: [(15, 4096), (12, 4096), (10, 4096)]
#   Negative shapes: [(10, 4096), (11, 4096), (12, 4096)]
# Warning: Inconsistent shapes in layer model.layers.1.post_attention_layernorm, skipping
#   Positive shapes: [(15, 4096), (12, 4096), (10, 4096)]
#   Negative shapes: [(10, 4096), (11, 4096), (12, 4096)]
# Warning: Inconsistent shapes in layer model.layers.2.post_attention_layernorm, skipping
#   Positive shapes: [(15, 4096), (12, 4096), (10, 4096)]
#   Negative shapes: [(10, 4096), (11, 4096), (12, 4096)]
# Warning: Inconsistent shapes in layer model.layers.0.mlp, skipping
#   Positive shapes: [(15, 4096), (12, 4096), (10, 4096)]
#   Negative shapes: [(10, 4096), (11, 4096), (12, 4096)]
# Warning: Inconsistent shapes in layer model.layers.0.mlp.gate_proj, skipping
#   Positive shapes: [(15, 14336), (12, 14336), (10, 14336)]
#   Negative shapes: [(10, 14336), (11, 14336), (12, 14336)]
# Warning: Inconsistent shapes in layer model.layers.0.mlp.up_proj, skipping
#   Positive shapes: [(15, 14336), (12, 14336), (10, 14336)]
#   Negative shapes: [(10, 14336), (11, 14336), (12, 14336)]
# Identified concept neurons for: technical_concept
# Write about climate change: its causes, effects, and solutions
# Climate change is one of the most pressing issues of our time. It refers to the long-term warming of the planet due to the increasing levels of greenhouse gases in the atmosphere. These gases, such as carbon dioxide, methane, and nitrous oxide, trap heat from the sun and prevent it from being released back into space, leading to a rise in global temperatures.
# Causes of Climate Change:
# The main causes of climate change are:
# 1. Burning of fossil fuels: The burning of coal, oil, and gas for energy releases large amounts of carbon dioxide into the atmosphere.
# 2. Deforestation: The clearing of forests for agriculture, urbanization, and other purposes releases carbon dioxide and reduces the ability of forests to act as carbon sinks.
# 3. Land use changes: The conversion of natural habitats into agricultural land, urban areas, and infrastructure projects leads to the release of stored carbon and the destruction of carbon-absorbing ecosystems.
# 4. Methane emissions: The production and transportation of natural gas, as well as the raising of livestock, release methane, a potent greenhouse gas.
# 5. Population growth and consumption patterns: As the global population grows, so does the demand for energy, food, and resources, leading increased greenhouse gas emissions.
#
# Effects of Climate change:
# Climate change has far-reaching and devastating effects on the environment, human health, and the economy. Some of the effects include:
#
# 1. Rising global temperatures: The average global temperature has risen by about

# %%
# Generate without manipulation (baseline)

prompt = "Write about climate change:"
plain_output = manipulator.generate_plain(prompt, max_new_tokens=300)

# Generate with erasure (subtracting a behavior pattern)
erasure_output = manipulator.generate_with_erasure(
    prompt, "formal_writing", erasure_strength=0.5,
    target_layers=target_layers, max_new_tokens=300
)

# Generate with amplification (enhancing a behavior pattern)
amplified_output = manipulator.generate_with_amplification(
    prompt, "creative_writing", amplification_factor=0.5,
    target_layers=target_layers, max_new_tokens=300
)

# Generate with interpolation (blending baseline and behavior)
interpolated_output = manipulator.generate_with_interpolation(
    prompt, "formal_writing", interpolation_factor=0.5,
    target_layers=target_layers, max_new_tokens=300
)
print(plain_output)
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
print(erasure_output)
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
print(amplified_output)
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
print(interpolated_output)
# Out:
# Write about climate change: The Role of Agriculture in Addressing Climate Change
# Climate change is a pressing global issue that affects the environment, human health, and the economy. One of the significant contributors to climate change is the agricultural sector, which accounts for around 24% of greenhouse gas (GHG) emissions globally. The primary GHGs emitted by agriculture are methane (CH4) and nitrous oxide (N2O), primarily from livestock production and fertilizer use.
# The livestock sector is a significant source of GHG emissions, with cattle, sheep, and goats being the main contributors. Livestock farming leads to the release of methane, a potent GHG, through flatulence, manure, and other biological processes. Additionally, the production of meat and dairy products requires large amounts of feed, which often involves deforestation, leading to the release of stored carbon into the atmosphere.
# Fertilizer use is another significant contributor to GHG emissions from agriculture. The production and application of synthetic fertilizers release nitrous oxide, a long-lived GHG with a high global warming potential. This is often a result of over-fertilization, which can lead to soil degradation, water pollution, and the release of nitrous oxide into the atmosphere.
# Agriculture can play a crucial role in addressing climate change by adopting sustainable practices and reducing GHG emissions. Some strategies for reducing GHG emissions from agriculture include:
#
# 1.  **Improving Livestock Feed Efficiency**: By improving feed efficiency, farmers can reduce the amount
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Write about climate change:  The world is in a state of panic due to the increasing threat of climate change. The  ice caps are melting,  the  oceans  are  rising,  and  the  weather  is  becoming  increasingly  unpredictable.  The  scientific  consensus  is  clear:  human  activities,  such  as  the  burning  of  fossil  fuels,  are  the  primary  cause  of  the  current  climate  crisis.  The  consequences  are  dire,  with  severe  and  unpredictable  impacts  on  ecosystems,  biodiversity,  and  human  societies  worldwide.  The  window  for  taking  collective  action  to  mitigate  the  worst  effects  of  climate  change  is  rapidly  closing.  It’s  time  to  take  drastic  and  urgent  measures  to  transition  to  a  low-carbon  economy,  invest  in  renewable  energy,  and  implement  sustainable  and  climate-resilient  infrastructure.
# However,  despite  the  gravity  of  the  situation,  there  are  many  who  still  deny  the  reality  of  climate  change,  and  its  impacts  are  being  largely  shouldered  by  the  most  vulnerable  and  marginalized  communities.  The  world
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Write about climate change: what is it, its effects, and ways to mitigate it.
# Climate change is a pressing global issue that has far-reaching consequences for the environment, economy, and human societies. It refers to the warming of the planet, leading to rising global temperatures, more frequent natural disasters, and altered weather patterns. The main cause of climate change is the increasing levels of greenhouse gases in the atmosphere, primarily carbon dioxide, which traps heat and contributes to global warming.
#
# Effects of Climate Change:
#
# 1.  Rising global temperatures: The average global temperature has risen by about 1.2 degrees Celsius since 1880, leading to more frequent and severe heatwaves, droughts, and other extreme weather events.
# 2.  Sea level rise: Thawing of polar ice caps and glaciers contribute to sea level rise, threatening coastal communities, cities, and ecosystems.
# 3.  Changes in precipitation patterns: Climate change leads to more frequent and intense droughts and floods, affecting agriculture, water resources, and human settlements.
# 4.  Loss of biodiversity: Climate change disrupts ecosystems, leading to extinctions, changes in species distribution, and altered food webs.
# 5.  Human health impacts: Climate change contributes to heat-related illnesses, respiratory issues, and spread of diseases, compromising human health and well-being.
#
# Ways to Mitigate Climate Change:
#
# 1.  **Renewable energy transition**: Shift from fossil fuels to solar, wind, and other renewable energy sources to reduce greenhouse gas emissions.
# 2.
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Write about climate change: what it is, its effects, and how it can be prevented or mitigated.
# Climate change is a global issue that has been gaining attention in recent years. It refers to the long-term warming of the planet due to human activities that release greenhouse gases, such as carbon dioxide, methane, and nitrous oxide, into the atmosphere. These gases trap heat from the sun, leading to a rise in global temperatures.
# The effects of climate change are far-reaching and devastating. Some of the most notable consequences include:
# Rising sea levels: Melting of polar ice caps and glaciers causes sea levels to rise, leading to coastal erosion, flooding, and saltwater contamination of freshwater sources.
# More frequent natural disasters: Climate change leads to more intense and frequent heatwaves, droughts, floods, and storms, resulting in loss of life, property damage, and displacement of communities.
# Changes in precipitation patterns: Alterations in precipitation patterns lead to droughts in some areas and floods in others, affecting agriculture, water supply, and ecosystems.
# Loss of biodiversity: Climate change disrupts ecosystems, leading to the extinction of plant and animal species that are unable to adapt to changing conditions.
# Negative impacts on human health: Climate change exacerbates respiratory issues, heat stress, and water-borne diseases, affecting vulnerable populations, such as the elderly, children, and those with pre-existing conditions.
# To prevent or mitigate climate change, individuals, organizations, and governments can take various actions:
# Reduce greenhouse gas emissions: Transition to renewable energy

# %%
# Generate without manipulation (baseline)

prompt = "Write about climate change:"
plain_output = manipulator.generate_plain(prompt, max_new_tokens=300)

# Generate with erasure (subtracting a behavior pattern)
erasure_output = manipulator.generate_with_erasure(
    prompt, "formal_writing", erasure_strength=0.5,
    target_layers=target_layers, max_new_tokens=300
)

# Generate with amplification (enhancing a behavior pattern)
amplified_output = manipulator.generate_with_amplification(
    prompt, "creative_writing", amplification_factor=0.6,
    target_layers=target_layers, max_new_tokens=300
)

# Generate with interpolation (blending baseline and behavior)
interpolated_output = manipulator.generate_with_interpolation(
    prompt, "formal_writing", interpolation_factor=0.6,
    target_layers=target_layers, max_new_tokens=300
)
print(plain_output)
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
print(erasure_output)
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
print(amplified_output)
print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
print(interpolated_output)
# Out:
# Write about climate change: Why should we care?
# Climate change is a pressing issue that affects everyone on the planet. Rising global temperatures are causing more extreme weather events, melting polar ice caps, and altering ecosystems. The consequences of climate change are far-reaching and devastating, impacting not only the environment but also human health, economies, and societies. So, why should we care?
# One reason to care is the impact on human health. Climate change is linked to an increased risk of heat stress, respiratory problems, and the spread of disease. Warmer temperatures also bring more intense heatwaves, which can be deadly, especially for vulnerable populations like the elderly and young children. In addition, climate change is expected to increase the spread of vector-borne diseases like malaria and dengue fever, further threatening human health.
# Another reason to care is the economic consequences of climate change. Rising sea levels and more frequent flooding are already causing significant damage to infrastructure, homes, and businesses, leading to costly repairs and reconstruction. Moreover, climate-related disasters are disrupting global supply chains, threatening food security, and straining economies. In the United States alone, the economic costs of climate-related disasters have exceeded $1 trillion since 1980.
# Climate change also has a profound impact on ecosystems and biodiversity. As temperatures rise, many species are shifting their ranges or going extinct, threatening the delicate balance of ecosystems and the services they provide, such as pollination, pest control, and nutrient cycling. The loss of biodiversity also has significant consequences for human well
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Write about climate change: a global issue with many local roots
#  The Earth is the only known planet in the universe with life, and it is our home. It is the source of all the air we breathe, the water we drink, and the food we eat. Despite its importance, the Earth is facing a global issue, which is the changing of the climate. The Earth’s climate is changing due to the increasing levels of greenhouse gases in the atmosphere, such as carbon dioxide and methane, which are primarily produced by human activities.
#  The main cause of the changing of the climate is the increasing levels of greenhouse gases in the atmosphere. The main sources of these gases are the fossil fuels, such as coal, oil, and natural gas, which are used to produce energy. The process of producing, transporting, and using these fuels releases large amounts of carbon dioxide and other greenhouse gases into the atmosphere, which trap the heat and lead to the rise in the Earth’s temperature.
#  The changing of the climate has a significant impact on the Earth’s ecosystems and the people who live on it. It is the main cause of the melting of the polar ice caps, the rising of the sea levels, and the increase in the frequency and severity of the extreme weather events, such as the droughts, the hurricanes, and the wildfires. The changing of the climate also affects the production of the food, which is the main source of the people’s livelihood.
#  The impact of the changing of the climate is not the same
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Write about climate change: the science, the solutions, and the personal connection
# Climate change is one of the most pressing global issues of our time, with far-reaching implications for our planet and our communities. As we face the challenges of a warming world, it’s essential to understand the science behind climate change, the solutions that are being developed, and how we can all play a role in addressing this issue.
#
# The science of climate change is clear: human activities, particularly the burning of fossil fuels and deforestation, are releasing greenhouse gases into the atmosphere, leading to global warming and its associated impacts. The consequences are already being felt, from record-breaking natural disasters to sea-level rise and melting of polar ice caps. The science is irrefutable: climate change is real, it’s happening now, and it’s having a profound impact on our planet.
#
# In the face of this reality, it’s natural to feel overwhelmed and uncertain about how to make a difference. However, there are solutions being developed and implemented that offer hope and possibility. From renewable energy technologies like solar and wind power to electric vehicles and sustainable agriculture, there are many ways to reduce our carbon footprint and transition to a more sustainable economy.
#
# For individuals, making a personal connection to climate change can be a powerful motivator for taking action. It’s essential to understand that every small action we take, from using public transportation to reducing our energy consumption, can make a difference.
#
# In this essay, I will explore the science of climate change, the solutions
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# Write about climate change: its causes and consequences.
# Climate change refers to the long-term warming of the planet, which is primarily caused by human activities that release greenhouse gases, such as carbon dioxide, methane, and nitrous oxide, into the atmosphere. These gases trap heat from the sun, leading to a rise in global temperatures. The consequences of climate change are far-reaching and devastating, affecting not only the environment but also human societies and economies.
# Causes of climate change:
# 1. **Burning of fossil fuels**: The largest contributor to climate change is the burning of fossil fuels, such as coal, oil, and natural gas, for energy production.
# 2. **Deforestation**: The clearing of forests for agriculture, urbanization, and other purposes releases carbon dioxide into the atmosphere and reduces the ability of forests to act as carbon sinks.
# 3. **Agricultural practices**: The production of meat, especially beef, and other animal products leads to the release of methane and nitrous oxide.
# 4. **Industrial processes**: The production of cement, steel, and other industrial processes also release large amounts of greenhouse gases.
# 5. **Population growth**: As the global population grows, so does the demand for energy, food, and other resources, leading to increased greenhouse gas emissions.
#
# Consequences of climate change:
# 1. **Rising global temperatures**: The average global temperature has risen by about 1°C since 1880, with more frequent and severe heatwaves, droughts, and wildfires.
# 2. **Sea-level
